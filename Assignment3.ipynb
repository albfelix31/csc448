# %% [markdown]
# <a href="https://colab.research.google.com/github/albfelix31/csc448/blob/main/Assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CSc 44800: Artificial Intelligence
# ## Assignment 3
# ### Albert Felix
# ### Prof. Hunter McNichols
# ### May 14th, 2021

# %% [markdown]
# ## Abstract

# %% [markdown]
# For this assignment, I found two very interesting datasets: one on chocolates and one on nintendo games. Being stuck at home quarantining for the past year has been pretty isolating and draining, but candies and video games have helped keep me afloat, which is why I chose these datasets. Both of these datasets contain some pretty interesting information, and were also collected very recently.
#
# I will be using the chocolates dataset for sections 1 and 2. I will use a Linear Regression to predict the rating of a specific chocolate bar based on its cocoa percentage. Furthermore, I will be using the nintendo games dataset for sections 3 and 4. I will perform a neural network algorithm to classify which platform a videogame belongs to based off its stats.
#
# Before digging in, let's start with importing the libraries that will be used throughout this assignment.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import sklearn
import sklearn.exceptions
import warnings
from sklearn import linear_model, preprocessing
from sklearn.linear_model import LinearRegression
from sklearn.metrics import classification_report, mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
warnings.filterwarnings("ignore", category=sklearn.exceptions.UndefinedMetricWarning)

# %% [markdown]
# ## Section 1: Prepping the Regression Dataset

# %% [markdown]
# The chocolates dataset contains several columns with information on different chocolate bars. This includes the company that produces the chocolate bar and where it is located, the rating of the chocolate bar and the year that it was reviewed, the origin of the beans used to make it, the cocoa percentage, number of ingredients as well as the different ingredients it may have, and the first, second, third, and fourth tastes it gives. Below we can take a closer look at some of this data:

# %%
chocolates = pd.read_csv("https://www.github.com/albfelix31/csc448/blob/main/Chocolate.csv?raw=true")
chocolates.head(15)
# Out:
#     Unnamed: 0   ref   company company_location  review_date  \
# 0            0  2454      5150            U.S.A         2019
# 1            1  2458      5150            U.S.A         2019
# 2            2  2454      5150            U.S.A         2019
# 3            3   797  A. Morin           France         2012
# 4            4   797  A. Morin           France         2012
# 5            5  1015  A. Morin           France         2013
# 6            6  1019  A. Morin           France         2013
# 7            7  1011  A. Morin           France         2013
# 8            8  1019  A. Morin           France         2013
# 9            9  1011  A. Morin           France         2013
# 10          10  1015  A. Morin           France         2013
# 11          11  1019  A. Morin           France         2013
# 12          12  1011  A. Morin           France         2013
# 13          13  1015  A. Morin           France         2013
# 14          14  1011  A. Morin           France         2013
#
#    country_of_bean_origin specific_bean_origin_or_bar_name  cocoa_percent  \
# 0              Madagascar           Bejofo Estate, batch 1           76.0
# 1      Dominican republic                  Zorzal, batch 1           76.0
# 2                Tanzania            Kokoa Kamili, batch 1           76.0
# 3                    Peru                             Peru           63.0
# 4                 Bolivia                          Bolivia           70.0
# 5               Venezuela                            Chuao           70.0
# 6                    Peru             Chanchamayo Province           63.0
# 7                 Ecuador                         Equateur           70.0
# 8                    Peru             Chanchamayo Province           70.0
# 9                  Brazil                           Brazil           70.0
# 10       Papua new guinea                 Papua New Guinea           70.0
# 11                   Peru                            Piura           70.0
# 12             Madagascar              Madagascar, Criollo           70.0
# 13                  Burma                         Birmanie           70.0
# 14                 Panama                           Panama           70.0
#
#     rating  counts_of_ingredients  ...       cocoa_butter          vanilla  \
# 0     3.75                      3  ...  have_cocoa_butter  have_not_vanila
# 1     3.50                      3  ...  have_cocoa_butter  have_not_vanila
# 2     3.25                      3  ...  have_cocoa_butter  have_not_vanila
# 3     3.75                      4  ...  have_cocoa_butter  have_not_vanila
# 4     3.50                      4  ...  have_cocoa_butter  have_not_vanila
# 5     4.00                      4  ...  have_cocoa_butter  have_not_vanila
# 6     4.00                      3  ...  have_cocoa_butter  have_not_vanila
# 7     3.75                      4  ...  have_cocoa_butter  have_not_vanila
# 8     3.50                      4  ...  have_cocoa_butter  have_not_vanila
# 9     3.25                      4  ...  have_cocoa_butter  have_not_vanila
# 10    3.25                      4  ...  have_cocoa_butter  have_not_vanila
# 11    3.25                      4  ...  have_cocoa_butter  have_not_vanila
# 12    3.00                      4  ...  have_cocoa_butter  have_not_vanila
# 13    3.00                      4  ...  have_cocoa_butter  have_not_vanila
# 14    2.75                      4  ...  have_cocoa_butter  have_not_vanila
#
#              lecithin           salt       sugar  \
# 0   have_not_lecithin  have_not_salt  have_sugar
# 1   have_not_lecithin  have_not_salt  have_sugar
# 2   have_not_lecithin  have_not_salt  have_sugar
# 3       have_lecithin  have_not_salt  have_sugar
# 4       have_lecithin  have_not_salt  have_sugar
# 5       have_lecithin  have_not_salt  have_sugar
# 6   have_not_lecithin  have_not_salt  have_sugar
# 7       have_lecithin  have_not_salt  have_sugar
# 8       have_lecithin  have_not_salt  have_sugar
# 9       have_lecithin  have_not_salt  have_sugar
# 10      have_lecithin  have_not_salt  have_sugar
# 11      have_lecithin  have_not_salt  have_sugar
# 12      have_lecithin  have_not_salt  have_sugar
# 13      have_lecithin  have_not_salt  have_sugar
# 14      have_lecithin  have_not_salt  have_sugar
#
#              sweetener_without_sugar       first_taste  second_taste  \
# 0   have_not_sweetener_without_sugar             cocoa    blackberry
# 1   have_not_sweetener_without_sugar             cocoa       vegetal
# 2   have_not_sweetener_without_sugar        rich cocoa         fatty
# 3   have_not_sweetener_without_sugar            fruity         melon
# 4   have_not_sweetener_without_sugar           vegetal         nutty
# 5   have_not_sweetener_without_sugar              oily           nut
# 6   have_not_sweetener_without_sugar             sweet         cocoa
# 7   have_not_sweetener_without_sugar             sandy         nutty
# 8   have_not_sweetener_without_sugar             cocoa          sour
# 9   have_not_sweetener_without_sugar      mild tobacco           NaN
# 10  have_not_sweetener_without_sugar        mild fruit  strong smoke
# 11  have_not_sweetener_without_sugar             green         nutty
# 12  have_not_sweetener_without_sugar            sticky     red fruit
# 13  have_not_sweetener_without_sugar            sticky        smokey
# 14  have_not_sweetener_without_sugar  brief fruit note        earthy
#
#           third_taste fourth_taste
# 0           full body          NaN
# 1              savory          NaN
# 2              bready          NaN
# 3              roasty          NaN
# 4                 NaN          NaN
# 5             caramel    raspberry
# 6           tangerine          NaN
# 7               cocoa          fig
# 8   intense tangerine          NaN
# 9                 NaN          NaN
# 10                NaN          NaN
# 11              cocoa          NaN
# 12               sour          NaN
# 13              grass          NaN
# 14              nutty          NaN
#
# [15 rows x 21 columns]

# %% [markdown]
# For the purpose of this assignment, we can just focus on the following columns:
# - **cocoa_percent:** percentage of cocoa in the chocolate bar
# - **rating:** rating for the chocolate bar
#
# Furthermore, it is important to note the details of the scale for the rating column:
# - 4.0 - 5.0 = Outstanding
# - 3.5 - 3.9 = Highly Recommended
# - 3.0 - 3.49 = Recommended
# - 2.0 - 2.9 = Disappointing
# - 1.0 - 1.9 = Unpleasant
#
# We can now drop the unnecessary columns and cleanup our data.

# %%
del chocolates['ref']
del chocolates['specific_bean_origin_or_bar_name']
del chocolates['cocoa_butter']
del chocolates['beans']
del chocolates['vanilla']
del chocolates['lecithin']
del chocolates['salt']
del chocolates['sugar']
del chocolates['sweetener_without_sugar']
del chocolates['first_taste']
del chocolates['second_taste']
del chocolates['third_taste']
del chocolates['fourth_taste']
del chocolates['Unnamed: 0']
del chocolates['company']
del chocolates['company_location']
del chocolates['review_date']
del chocolates['country_of_bean_origin']
del chocolates['counts_of_ingredients']

# data in these columns is given in string format, so we can convert it to floating point numbers
chocolates["cocoa_percent"] = pd.to_numeric(chocolates["cocoa_percent"], downcast="float")
chocolates["rating"] = pd.to_numeric(chocolates["rating"], downcast="float")

# %% [markdown]
# Now, the head of our dataset looks more like this:

# %%
chocolates.head(15)
# Out:
#     cocoa_percent  rating
# 0            76.0    3.75
# 1            76.0    3.50
# 2            76.0    3.25
# 3            63.0    3.75
# 4            70.0    3.50
# 5            70.0    4.00
# 6            63.0    4.00
# 7            70.0    3.75
# 8            70.0    3.50
# 9            70.0    3.25
# 10           70.0    3.25
# 11           70.0    3.25
# 12           70.0    3.00
# 13           70.0    3.00
# 14           70.0    2.75

# %% [markdown]
# In our linear regression, we will utilize the data on the rating and cocoa_percent columns. Our goal is to see if the cocoa percentage of a chocolate bar can be used to predict how it would be rated.

# %% [markdown]
# ## Section 2: Linear Regression

# %% [markdown]
# Now that we have taken a quick look through our dataset, it's time to AI it up!
#
# First, we select the columns that we will utilize for our linear regression. My hypothesis is that the higher the cocoa percentage that a chocolate bar has, the higher it would be rated. As such, we select the columns in our dataset that represent this data.

# %%
rating = chocolates[['rating']]
cocoaPercentage = chocolates[['cocoa_percent']]

# %% [markdown]
# We can then use sklearn to create our training and test sets. 20% of the dataset will be reserved for testing. This data will be split as follows:
#
# - **x_train:** cocoa percentage values used for training the regression model
# - **y_train:** rating values used for training the regression model
# - **x_test:** cocoa percentage values used for testing the regression model
# - **y_test:** rating values used for testing the regression model

# %%
x_train, x_test, y_train, y_test = train_test_split(cocoaPercentage, rating, test_size=0.2, shuffle=True)

# %% [markdown]
# Using sklearn, we can fit a linear regression into our training set and create our model. We can do this as follows:

# %%
reg = LinearRegression().fit(x_train, y_train)

# %% [markdown]
# After training our model, we can move on to testing it. For this, we make use of the predict function, inputting our x_test as its argument. This will give us a prediction of the different ratings for each chocolate bar based on their cocoa percentage that is given in the x_test array.
#
# We can see how these values fare by comparing them with the y_test values. We can do this for the first 15 values of each one.

# %%
y_pred = reg.predict(x_test)

for i in range(15):
    x_val = x_test.head(15).values.tolist()[i][0]
    pred_val = round(y_pred[i][0],2)
    actual_val = y_test.head(15).values.tolist()[i][0]
    print("Cocoa percentage:", x_val, "| Predicted rating:", pred_val, "| Actual rating:", actual_val)
# Out:
# Cocoa percentage: 75.0 | Predicted rating: 3.17 | Actual rating: 3.0
# Cocoa percentage: 75.0 | Predicted rating: 3.17 | Actual rating: 3.25
# Cocoa percentage: 68.0 | Predicted rating: 3.22 | Actual rating: 3.25
# Cocoa percentage: 72.0 | Predicted rating: 3.19 | Actual rating: 3.25
# Cocoa percentage: 85.0 | Predicted rating: 3.12 | Actual rating: 3.5
# Cocoa percentage: 75.0 | Predicted rating: 3.17 | Actual rating: 3.0
# Cocoa percentage: 70.0 | Predicted rating: 3.2 | Actual rating: 3.0
# Cocoa percentage: 75.0 | Predicted rating: 3.17 | Actual rating: 3.5
# Cocoa percentage: 71.0 | Predicted rating: 3.2 | Actual rating: 2.5
# Cocoa percentage: 75.0 | Predicted rating: 3.17 | Actual rating: 2.75
# Cocoa percentage: 70.0 | Predicted rating: 3.2 | Actual rating: 3.5
# Cocoa percentage: 70.0 | Predicted rating: 3.2 | Actual rating: 3.0
# Cocoa percentage: 67.0 | Predicted rating: 3.22 | Actual rating: 3.75
# Cocoa percentage: 70.0 | Predicted rating: 3.2 | Actual rating: 4.0
# Cocoa percentage: 70.0 | Predicted rating: 3.2 | Actual rating: 2.5

# %% [markdown]
# Though the results here don't look too promising, we can still plot our data and see what we find.
#
# In our data visualization, the training data will be represented in blue dots, whereas the test data will be represented in green dots. Furthermore, we will represent our regression line in red.

# %%
plt.rcParams["figure.figsize"] = (15,15)
plt.xlabel("Cocoa Percentage")
plt.ylabel("Chocolate Rating")
plt.title("Chocolate Rating Prediction Based on Cocoa Percentage")

plt.scatter(x_train, y_train, color='blue')
plt.scatter(x_test, y_test, color='green')
plt.plot(x_test, y_pred, color='red', linewidth=3)

plt.show()

# %% [markdown]
# Not looking too good. Let us follow up with checking out the error rate of this model.

# %%
print('Mean Squared Error:', mean_squared_error(y_test, y_pred))
# Compute model error rate
score = reg.score(x_test, y_test)
print('Model error rate:', round(score,2))
# Out:
# Mean Squared Error: 0.18603456
# Model error rate: 0.01

# %% [markdown]
# **Results Discussion**
#
# This model has a mean squared error of 0.186, and an error rate of 0.01, both of which are very low. This tells us that our model is not very accurate at predicting how well a chocolate bar would be rated based on its cocoa percentage. I believe that there are many reasons for this. First, the chocolate ratings are very evenly spread across each rating, telling us that there may not be any correlation between the two features. Second, there are many other different features that could affect a chocolate bar's rating, such as the number of ingredients or its different tastes.

# %% [markdown]
# ## Section 3: Prepping the Classification Dataset

# %% [markdown]
# The Nintendo Games dataset contains data on different video games. This includes the game title, the platform where it is played, the date it was released, user score and meta score, ESRB (Entertainment Software Rating Board) rating, its developers, and its genre. Below we can take a look at some of this data:

# %%
nintendoGames = pd.read_csv("https://www.github.com/albfelix31/csc448/blob/main/NintendoGames.csv?raw=true")
nintendoGames.head(15)
# Out:
#     meta_score                                              title platform  \
# 0          NaN               Super Mario 3D World + Bowser's Fury   Switch
# 1          NaN              Super Smash Bros. Ultimate: Sephiroth   Switch
# 2         66.0                Fitness Boxing 2: Rhythm & Exercise   Switch
# 3         63.0    Fire Emblem: Shadow Dragon & the Blade of Light   Switch
# 4         79.0                   Hyrule Warriors: Age of Calamity   Switch
# 5          NaN       Pokemon Sword + Pokemon Sword Expansion Pass   Switch
# 6          NaN     Pokemon Shield + Pokemon Shield Expansion Pass   Switch
# 7         85.0                                    Pikmin 3 Deluxe   Switch
# 8         79.0                                      Part Time UFO   Switch
# 9          NaN  Cadence of Hyrule: Crypt of the NecroDancer Fe...   Switch
# 10        75.0           Pokemon Sword / Shield: The Crown Tundra   Switch
# 11        75.0                      Mario Kart Live: Home Circuit   Switch
# 12         NaN           Super Smash Bros. Ultimate: Steve & Alex   Switch
# 13         NaN            Mario Kart 8 Deluxe + Super Mario Party   Switch
# 14        75.0                               Super Mario Bros. 35   Switch
#
#             date  user_score  \
# 0   Feb 12, 2021         NaN
# 1   Dec 22, 2020         NaN
# 2    Dec 4, 2020         6.2
# 3    Dec 4, 2020         7.6
# 4   Nov 20, 2020         8.1
# 5    Nov 6, 2020         6.7
# 6    Nov 6, 2020         6.6
# 7   Oct 30, 2020         8.4
# 8   Oct 28, 2020         7.3
# 9   Oct 23, 2020         NaN
# 10  Oct 22, 2020         7.4
# 11  Oct 16, 2020         7.3
# 12  Oct 13, 2020         9.3
# 13   Oct 4, 2020         NaN
# 14   Oct 1, 2020         7.5
#
#                                                  link esrb_rating  \
# 0    /game/switch/super-mario-3d-world-+-bowsers-fury         NaN
# 1    /game/switch/super-smash-bros-ultimate-sephiroth         NaN
# 2       /game/switch/fitness-boxing-2-rhythm-exercise           E
# 3   /game/switch/fire-emblem-shadow-dragon-the-bla...           E
# 4        /game/switch/hyrule-warriors-age-of-calamity           T
# 5   /game/switch/pokemon-sword-+-pokemon-sword-exp...           E
# 6   /game/switch/pokemon-shield-+-pokemon-shield-e...           E
# 7                        /game/switch/pikmin-3-deluxe        E10+
# 8                          /game/switch/part-time-ufo        E10+
# 9   /game/switch/cadence-of-hyrule-crypt-of-the-ne...           E
# 10  /game/switch/pokemon-sword-shield-the-crown-tu...         NaN
# 11          /game/switch/mario-kart-live-home-circuit           E
# 12  /game/switch/super-smash-bros-ultimate-steve-alex        E10+
# 13  /game/switch/mario-kart-8-deluxe-+-super-mario...           E
# 14                   /game/switch/super-mario-bros-35         NaN
#
#                                 developers  \
# 0                             ['Nintendo']
# 1                             ['Nintendo']
# 2   ['Nintendo', ' Imagineer Co.', 'Ltd.']
# 3                  ['Intelligent Systems']
# 4     ['Omega Force', ' Koei Tecmo Games']
# 5                           ['Game Freak']
# 6                           ['Game Freak']
# 7                ['Eighting', ' Nintendo']
# 8                             ['HAL Labs']
# 9                 ['Brace Yourself Games']
# 10                          ['Game Freak']
# 11          ['Nintendo', ' Velan Studios']
# 12                            ['Nintendo']
# 13                            ['Nintendo']
# 14                            ['Nintendo']
#
#                                      genres
# 0            ['Action', 'Platformer', '3D']
# 1              ['Action', '2D', 'Fighting']
# 2   ['Miscellaneous', 'Exercise / Fitness']
# 3     ['Strategy', 'Turn-Based', 'Tactics']
# 4           ['Action', "Beat-'Em-Up", '3D']
# 5               ['Role-Playing', 'Trainer']
# 6               ['Role-Playing', 'Trainer']
# 7      ['Strategy', 'Real-Time', 'General']
# 8                      ['Action', 'Arcade']
# 9             ['Action', 'Rhythm', 'Music']
# 10              ['Role-Playing', 'Trainer']
# 11       ['Racing', 'Arcade', 'Automobile']
# 12             ['Action', 'Fighting', '2D']
# 13         ['Miscellaneous', 'Compilation']
# 14           ['Action', 'Platformer', '2D']

# %% [markdown]
# Our goal in this assignment is to see whether we can use data on video games such as ESRB rating, user score, and meta score to determine the platform that a game belongs to. As such, let us summarize some of this information below:
#
# - **ESRB Rating:** possible values include 'E', 'T', 'E10+', and 'M'
# - **Platform:** possible values include 'Switch', 'iOS', '3DS', 'WIIU', 'DS', 'WII', 'GBA', 'GC', and 'N64'
# - **User Score:** values may range between 0 and 100
# - **Meta Score:** values may range between 0 and 100
#
# For ESRB rating and platform, values will be mapped as follows:
#
# <ins>ESRB Rating</ins>
# - 'E': 0
# - 'T': 1
# - 'E10+': 2
# - 'M': 3
#
# <ins>Platform</ins>
# - 'Switch': 0
# - 'iOS': 1
# - '3DS': 2
# - 'WIIU': 3
# - 'DS': 4
# - 'WII': 5
# - 'GBA': 6
# - 'GC': 7
# - 'N64': 8
#
# Now let us clean up our data, drop the columns we will not be using, and map our data on ESRB rating and platform columns to the values we assigned them:

# %%
nintendoGames = nintendoGames.dropna()
del nintendoGames['link']
del nintendoGames['date']
del nintendoGames['developers']
del nintendoGames['genres']
nintendoGames["platform"].replace({"Switch": 0, "iOS": 1, "3DS": 2, "WIIU": 3, 
                                   "DS": 4, "WII": 5, "GBA": 6, "GC": 7, "N64": 8}, inplace=True)
nintendoGames["esrb_rating"].replace({"E": 0, "T": 1, "E10+": 2, "M": 3}, inplace=True)
nintendoGames["meta_score"] = pd.to_numeric(nintendoGames["meta_score"], downcast="float")
nintendoGames["user_score"] = pd.to_numeric(nintendoGames["user_score"], downcast="float")
nintendoGames.head(15)
# Out:
#     meta_score                                            title  platform  \
# 2         66.0              Fitness Boxing 2: Rhythm & Exercise         0
# 3         63.0  Fire Emblem: Shadow Dragon & the Blade of Light         0
# 4         79.0                 Hyrule Warriors: Age of Calamity         0
# 7         85.0                                  Pikmin 3 Deluxe         0
# 8         79.0                                    Part Time UFO         0
# 11        75.0                    Mario Kart Live: Home Circuit         0
# 17        82.0                         Super Mario 3D All-Stars         0
# 20        80.0                    Paper Mario: The Origami King         0
# 22        64.0                                 Pokemon Cafe Mix         0
# 23        69.0        Pokemon Sword / Shield: The Isle of Armor         0
# 25        82.0           Clubhouse Games: 51 Worldwide Classics         0
# 26        89.0         Xenoblade Chronicles: Definitive Edition         0
# 29        78.0                                        Good Job!         0
# 30        90.0                    Animal Crossing: New Horizons         0
# 31        68.0          Pokemon Mystery Dungeon: Rescue Team DX         0
#
#     user_score  esrb_rating
# 2          6.2            0
# 3          7.6            0
# 4          8.1            1
# 7          8.4            2
# 8          7.3            2
# 11         7.3            0
# 17         6.3            0
# 20         7.0            0
# 22         7.7            0
# 23         5.3            0
# 25         7.8            0
# 26         8.9            1
# 29         7.7            0
# 30         5.5            0
# 31         8.2            0

# %% [markdown]
# With our data cleaned and mapped as needed, we can now move on to some AI model learning and data classification.

# %% [markdown]
# ## Section 4: Classification with a Neural Network

# %% [markdown]
# For this section, we will use ESRB rating, user score, and meta score to predict the platform that a video game belongs to. We will do this using the neural network classification algorithm.
#
# To start off, we will split our data into a training and test set, reserving 20% of our dataset for testing. We will  split our data as follows:
#
# - **x_train:** ESRB rating, user score, and meta score data reserved for training our model
# - **y_train:** game platform data reserved for training our model
# - **x_test:** ESRB rating, user score, and meta score data reserved for testing our model
# - **y_test:** game platform data reserved for testing our model

# %%
x = nintendoGames[["meta_score", "user_score", "esrb_rating"]]
y = nintendoGames['platform']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, shuffle=True)

# %% [markdown]
# Next, we must scale our data for our neural network. We do this because it allows for gradient descent to converge at a faster rate, speeds up learning, and ensures that our selected features will not contain higher value ranges dominating our distance calculations. Thus, I will use the StandardScaler function from sklearn to standardize our dataset values.

# %%
scaler = preprocessing.StandardScaler()  
scaler.fit(x_train)  
x_train = scaler.transform(x_train)  
x_test = scaler.transform(x_test)

# %% [markdown]
# We can now move on to building our classifier and fitting it to our training set! Again, for this assignment, I will be fitting the Neural Network Algorithm into our dataset. It will have 3 hidden layers with 8 nodes per layer. We will use the Multi-Layer Perceptron Classifier (MLPClassifier) from sklearn for this.

# %%
classifier = MLPClassifier(hidden_layer_sizes=(8,8,8), activation='relu', solver='adam', max_iter=3000)
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
predict_train = classifier.predict(x_train)
predict_test = classifier.predict(x_test)

# %% [markdown]
# Lastly, we can report on the error rate of our algorithm to measure its accuracy. We can also check out the classification_report of how well our algorithm performs.

# %%
print(classification_report(y_train, predict_train))
print("Accuracy of MLPClassifier: ", classifier.score(x_test, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.32      0.39        65
#            1       0.00      0.00      0.00         4
#            2       0.44      0.65      0.53       120
#            3       0.38      0.07      0.12        41
#            4       0.35      0.58      0.43        91
#            5       0.45      0.25      0.32        56
#            6       0.35      0.53      0.42        45
#            7       0.67      0.06      0.11        35
#            8       0.00      0.00      0.00        25
#
#     accuracy                           0.40       482
#    macro avg       0.35      0.27      0.26       482
# weighted avg       0.41      0.40      0.36       482
#
# Accuracy of MLPClassifier:  0.30578512396694213

# %% [markdown]
# **Results Discussion**
#
# This model has an accuracy rate of 0.3058, which is a very low value. This tells us that our model is not very accurate at classifying a video game into its platform based on its user score, meta score, and ESRB rating. We were able to correctly predict the platform of a video game 30.58% of the time, which is not too good. I believe that the reasoning for this could be that, like with the chocolates bar, there are other factors at play that can influence this, such as the developers and genre of the video game.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# In this assignment, I gained a better understanding of machine learning through implementing a linear regresion and a classification algorithm on two rich datasets.
#
# For the first part, I analyzed a chocolates bar dataset, which contains data on different chocolate bars, such as cocoa percentage, rating, number of ingredients, and its different tastes. I conducted a linear regression to see if we can predict how a chocolate would rate based on its cocoa percentage. This resulted in very low error rates, with a Mean Squared Error of 0.186, and a Model error rate of 0.01.
#
# For the second part, I analyzed a video games dataset, which contains data on different video games, such as ESRB rating, user score, meta score, its developers, and its genres. I conducted a classification with the neural network algorithm to see if we can predict what platform a video game belongs to based on its ESRB rating, user score, and meta score. This resulted in a very low accuracy rate of 0.3058.
#
# Though the results were not very promising, this work still allowed me to better understand how machine learning methods such as linear regression and neural network classification work. Furthermore, I was also able to play around with Python libraries that I was not familiar with, such as pandas and sklearn, which will come in very handy in future courseworks. I was also very surprised at how easy it is to train a learning model with sklearn.
#
# In a future version, I would extend the work on this assignment further by perhaps seeing how other features would affect what I'm trying to predict. For example, for the chocolates dataset, I would try to see if the number of ingredients in a chocolate bar can predict how well it would be rated in comparison to the cocoa percentage. For the videogames dataset, I would try to see if other features like genre and developers factor in the classification. Lastly, I would also expand this report using other methods like k-fold cross validation and random forest regression.
